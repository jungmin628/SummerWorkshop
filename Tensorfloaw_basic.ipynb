# %% [markdown]
# <a href="https://colab.research.google.com/github/jungmin628/SummerWorkshop/blob/master/Tensorfloaw_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow.compat.v1 as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
num_points = 1000
vectors_set = []
for i in range(num_points):
  x1= np.random.normal(0.0,0.55)
  y1 = x1*0.1+0.3+np.random.normal(0.0,0.03)
  vectors_set.append([x1,y1])

x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

plt.plot(x_data,y_data, 'ro')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
num_points = 1000
vectors_set = []
for i in range(num_points):
  x1= np.random.normal(0.0,0.55)
  y1 = x1*0.1+0.3+np.random.normal(0.0,0.03)
  vectors_set.append([x1,y1])

x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

plt.plot(x_data,y_data, 'ro')
plt.legend()
plt.show()

W = tf.Variable(tf.random.uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y = W*x_data + b

# 경사 하강법
loss = tf.reduce_mean(tf.square(y - y_data)) #평균제곱오차
#optimizer = tf.train.GradientDescentOptimizer(0.5)
#train = optimizer.minimize(loss)
opt = tf.keras.optivizers.Adam(learnimg_rate = 0.01)

init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

for step in range(8):
  sess.run(train)

print(sess.run(W), sess.run(b))
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e677bea303c9> in <module>()
#      21 #optimizer = tf.train.GradientDescentOptimizer(0.5)
#      22 #train = optimizer.minimize(loss)
# ---> 23 opt = tf.keras.optivizers.Adam(learnimg_rate = 0.01)
#      24
#      25 init = tf.initialize_all_variables()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/module_wrapper.py in _getattr(self, name)
#     230     """
#     231     try:
# --> 232       attr = getattr(self._tfmw_wrapped_module, name)
#     233     except AttributeError:
#     234     # Placeholder for Google-internal contrib error
#
# AttributeError: module 'keras.api._v1.keras' has no attribute 'optivizers'

# %%
_tall = 170
_kg = 70

wValue = tf.Variable(0.1)
bias = tf.Variable(0.1)

def lossFunction():
  result = _tall*wValue+bias
  return tf.square(_kg - result)

opt = tf.keras.optimizers.Adam(learning_rate = 0.1)

for i in range(300):
  opt.minimize(lossFunction, var_list=[wValue,bias])
  print(wValue.numpy(),bias.numpy())

init = tf.initialize_all_variables()
# Out:
# 0.2 0.2
# 0.29720435 0.29720435
# 0.38754937 0.38754937
# 0.46468675 0.46468675
# 0.52157533 0.52157533
# 0.55441326 0.55441326
# 0.5645202 0.5645202
# 0.55621517 0.55621517
# 0.53434205 0.53434205
# 0.5033106 0.5033106
# 0.46705666 0.46705666
# 0.4292278 0.4292278
# 0.39327547 0.39327547
# 0.36233428 0.36233428
# 0.33890936 0.33890936
# 0.3245411 0.3245411
# 0.31965685 0.31965685
# 0.32367858 0.32367858
# 0.33527973 0.33527973
# 0.35264847 0.35264847
# 0.40935907 0.40935907
# 0.4093592 0.4093592
# 0.40935862 0.40935862
# 0.40935758 0.40935758
# 0.40935642 0.40935642
# 0.40935546 0.40935546
# 0.40935493 0.40935493
# 0.40935495 0.40935495
# 0.4093555 0.4093555
# 0.40935633 0.40935633
# 0.4093572 0.4093572
# 0.40935785 0.40935785
# 0.4093581 0.4093581
# 0.40935796 0.40935796
# 0.4093575 0.4093575
# 0.40935683 0.40935683
# 0.40935624 0.40935624
# 0.40935582 0.40935582
# 0.4093557 0.4093557
# 0.40935588 0.40935588
# 0.4093563 0.4093563
# 0.4093568 0.4093568
# 0.40935722 0.40935722
# 0.40935746 0.40935746
# 0.40935746 0.40935746
# 0.40935725 0.40935725
# 0.40935692 0.40935692
# 0.4093566 0.4093566
# 0.40935633 0.40935633
# 0.4093562 0.4093562
# 0.40935627 0.40935627
# 0.40935645 0.40935645
# 0.40935668 0.40935668
# 0.40935692 0.40935692
# 0.40935707 0.40935707
# 0.4093571 0.4093571
# 0.40935704 0.40935704
# 0.4093569 0.4093569
# 0.4093567 0.4093567
# 0.40935653 0.40935653
# 0.40935645 0.40935645
# 0.40935645 0.40935645
# 0.4093565 0.4093565
# 0.40935662 0.40935662
# 0.40935677 0.40935677
# 0.4093569 0.4093569
# 0.40935695 0.40935695
# 0.40935692 0.40935692
# 0.40935683 0.40935683
# 0.40935674 0.40935674
# 0.40935665 0.40935665
# 0.4093566 0.4093566
# 0.4093566 0.4093566
# 0.40935662 0.40935662
# 0.40935668 0.40935668
# 0.40935674 0.40935674
# 0.4093568 0.4093568
# 0.40935683 0.40935683
# 0.40935683 0.40935683
# 0.4093568 0.4093568
# 0.40935674 0.40935674
# 0.40935668 0.40935668
# 0.40935665 0.40935665
# 0.40935665 0.40935665
# 0.40935668 0.40935668
# 0.4093567 0.4093567
# 0.40935674 0.40935674
# 0.40935677 0.40935677
# 0.4093568 0.4093568
# 0.4093568 0.4093568
# 0.40935677 0.40935677
# 0.4093567 0.4093567
# 0.40935665 0.40935665
# 0.40935665 0.40935665
# 0.40935668 0.40935668
# 0.4093567 0.4093567
# 0.40935674 0.40935674
# 0.40935677 0.40935677
# 0.40935677 0.40935677
# 0.40935677 0.40935677
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-9f2e54d009b6> in <module>()
#      17 init = tf.initialize_all_variables()
#      18 sess = tf.Session()
# ---> 19 sess.run(init)
#      20
#      21 plt.plot(sess.run(opt))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     966     try:
#     967       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 968                          run_metadata_ptr)
#     969       if run_metadata:
#     970         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1115       raise RuntimeError('Attempted to use a closed Session.')
#    1116     if self.graph.version == 0:
# -> 1117       raise RuntimeError('The Session graph is empty. Add operations to the '
#    1118                          'graph before calling run().')
#    1119
#
# RuntimeError: The Session graph is empty. Add operations to the graph before calling run().
